# %% [markdown]
# # IMPORT Libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import data set

# %%
data =pd.read_csv("C:/Users/User/Desktop/Dr Ammar/Machine Learning/MLRegression/heart.data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     biking    smoking  heart.disease
# 0           1  30.801246  10.896608      11.769423
# 1           2  65.129215   2.219563       2.854081
# 2           3   1.959665  17.588331      17.177803
# 3           4  44.800196   2.802559       6.816647
# 4           5  69.428454  15.974505       4.062224

# %% [markdown]
# # Exploratoy Data Analysis

# %%
data.describe().round()
# Out:
#        Unnamed: 0  biking  smoking  heart.disease
# count       498.0   498.0    498.0          498.0
# mean        250.0    38.0     15.0           10.0
# std         144.0    21.0      8.0            5.0
# min           1.0     1.0      1.0            1.0
# 25%         125.0    20.0      8.0            7.0
# 50%         250.0    36.0     16.0           10.0
# 75%         374.0    58.0     23.0           14.0
# max         498.0    75.0     30.0           20.0

# %%
plt.figure(figsize=(16,8))
plt.scatter( data['biking'], data['heart.disease'])
plt.xlabel('biking')
plt.ylabel('heart.disease')
plt.title('ML Graph')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter( data['smoking'], data['heart.disease'])
plt.xlabel('smoking')
plt.ylabel('heart.disease')
plt.title('ML Graph')
plt.show()

# %% [markdown]
# # 3d graph

# %%
fig = plt.figure(figsize=(16,8))
ax= fig.add_subplot(111, projection='3d')
plt.scatter(data['smoking'],data['biking'],data['heart.disease'])

# %% [markdown]
# # data preprocessing

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# biking           0
# smoking          0
# heart.disease    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     498 non-null    int64
#  1   biking         498 non-null    float64
#  2   smoking        498 non-null    float64
#  3   heart.disease  498 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 15.7 KB

# %%
plt.figure(figsize=(17,8))
plt.subplot(3,1,1)
sns.boxplot(data['heart.disease'])

plt.subplot(3,1,2)
sns.boxplot(data['biking'])


plt.subplot(3,1,3)
sns.boxplot(data['smoking'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # spliting of data set

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'biking', 'smoking', 'heart.disease'], dtype='object')

# %%
x= data[['biking','smoking']]
# x= data[['biking']]
#x=data.drop(['heart.disease'],axis=1)
y =data[['heart.disease']]

# %%
x.head()
# Out:
#       biking    smoking
# 0  30.801246  10.896608
# 1  65.129215   2.219563
# 2   1.959665  17.588331
# 3  44.800196   2.802559
# 4  69.428454  15.974505

# %%
y.head()
# Out:
#    heart.disease
# 0      11.769423
# 1       2.854081
# 2      17.177803
# 3       6.816647
# 4       4.062224

# %% [markdown]
# # Split data set Test and train

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train , y_test =train_test_split(x,y ,test_size=0.2 ,random_state=0)

# %%
print('shape of x train data_set =' , x_train.shape)
print('shape of y train data_set =' , y_train.shape)
print('shape of x test data_set =' , x_test.shape)
print('shape of y test data_set =' , y_test.shape)
# Out:
# shape of x train data_set = (398, 2)
# shape of y train data_set = (398, 1)
# shape of x test data_set = (100, 2)
# shape of y test data_set = (100, 1)

# %%
x_test[['smoking']]
# Out:
#        smoking
# 90   26.105658
# 254  27.324029
# 283  28.206910
# 443   1.751719
# 336  15.546870
# ..         ...
# 391  11.219860
# 56   22.976002
# 438   9.906249
# 60    0.767680
# 208  26.826971
#
# [100 rows x 1 columns]

# %%
x_test[['biking']]
# Out:
#         biking
# 90    6.947463
# 254  51.900538
# 283   1.466301
# 443   2.010308
# 336   6.178654
# ..         ...
# 391  70.578968
# 56   21.460016
# 438  63.753105
# 60   39.010480
# 208   7.831481
#
# [100 rows x 1 columns]

# %% [markdown]
# # fit multiple linear regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train , y_train)

# %%
model
# Out:
# LinearRegression()

# %% [markdown]
# # Model Equation

# %%
print(' intercept :',model.intercept_)
print('coefficient :', model.coef_ )
# Out:
#  intercept : [15.00897294]
# coefficient : [[-0.20037061  0.17666304]]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'biking', 'smoking', 'heart.disease'], dtype='object')

# %%
model.predict([[3,7]])
# Out:
# array([[15.64450242]])

# %% [markdown]
# # ploting

# %%
fig = plt.figure()
ax= fig.add_subplot(111, projection='3d')
plt.scatter(x_train['smoking'],x_train['biking'], y_train)
#plt.plot(x_test['smoking'],model.predict(x_test) , color ='red')
plt.xlabel('smolikng')
plt.ylabel('heart.disease')
plt.title('Train plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plt.figure()
ax= fig.add_subplot(111, projection='3d')
plt.scatter(x_test['smoking'],x_test['biking'],y_test )
# plt.plot(x_test['smoking'] ,model.predict(x_test) , color ='red')
plt.xlabel('smoking')
plt.ylabel('heart.disease')
plt.title('Test plot')
plt.show()

# %% [markdown]
# # model fittness

# %%
model.score(x_test ,y_test)
# Out:
# 0.9831624251492118

# %%
model.score(x_train , y_train)
# Out:
# 0.9785746181326694

# %%
print('Score for test model =' , model.score(x_test , y_test)  )
print('Score for train model =' , model.score(x_train , y_train) )
# Out:
# Score for test model = 0.9831624251492118
# Score for train model = 0.9785746181326694

# %% [markdown]
# # Predict for unkown value

# %%
model.predict([[7,9]])
# Out:
# array([[15.19634606]])

# %%
model.predict([[2,4] ,[3,8] ,[4,7]])
# Out:
# array([[15.3148839 ],
#        [15.82116546],
#        [15.4441318 ]])

# %%
x=([3,2],[4,3],[8,7])
model.predict(x)
# Out:
# array([[14.7611872 ],
#        [14.73747963],
#        [14.64264936]])

# %%
model.predict([[12,3]])
# Out:
# array([[13.13451475]])

# %% [markdown]
# ## Actual value and the predicted value

# %%
mlr_diff ={'Actual_value': y_test ,   'predicted_value': model.predict(x_test)}
mlr_diff
# Out:
# {'Actual_value':      heart.disease
#  90       18.689798
#  254       9.594623
#  283      20.185291
#  443      14.007490
#  336      15.977852
#  ..             ...
#  391       2.654706
#  56       15.008634
#  438       3.402080
#  60        8.763930
#  208      17.560451
#
#  [100 rows x 1 columns],
#  'predicted_value': array([[18.22881049],
#         [ 9.43677654],
#         [19.69828803],
#         [14.9156304 ],
#         [16.5175097 ],
#         [ 8.0493171 ],
#         [10.89345325],
#         [ 5.58794579],
#         [18.55102158],
#         [11.24860058],
#         [ 7.0211996 ],
#         [ 9.42561612],
#         [ 4.07516254],
#         [ 7.37070498],
#         [ 6.56203588],
#         [16.8763469 ],
#         [ 4.05816828],
#         [15.09078204],
#         [ 4.82451853],
#         [13.36017636],
#         [ 7.35206422],
#         [ 7.05600091],
#         [17.31415716],
#         [ 8.66093517],
#         [11.91309149],
#         [13.27757779],
# ...

# %% [markdown]
# # Future Prediction

# %%
model.predict([[12,17]])
# Out:
# array([[15.60779735]])

# %% [markdown]
# # Error

# %%
from sklearn import metrics

# %%
print('mean absolute error' , metrics.mean_absolute_error(y_test,model.predict(x_test)))
# Out:
# mean absolute error 0.5001944611523572

# %%
print('mean square error', metrics.mean_squared_error(y_test,model.predict(x_test)) )
# Out:
# mean square error 0.3820851882904314

# %%
print('root mean square error',np.sqrt(metrics.mean_squared_error(y_test,model.predict(x_test))) )
# Out:
# root mean square error 0.6181303974813336

# %%
print('r square error',metrics.r2_score(y_test , model.predict(x_test)))
# Out:
# r square error 0.9831624251492118

# %%
# adjestic r2
r2=metrics.r2_score(y_test , model.predict(x_test))
print('adjusted r2', 1-((1-r2)*(40-1)/(40-1-1)))
# Out:
# adjusted r2 0.9827193310741911

# %% [markdown]
# # Conclusion
#
# The Multiple Linear Regression model performs well as 98.27% of the data fit the regression model.
